# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## reading file

# %%
df = pd.read_csv('/content/best-selling-books.csv')
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %% [markdown]
# #Here's a brief description of each column:
# 1.	Book: The title or name of the book.
# 2.	Author(s): The author or authors who wrote the book.
# 3.	Original Language: The language in which the book was originally written.
# 4.	First Published: The date when the book was first published.
# 5.	Approximate Sales in Millions: The approximate number of book copies sold in millions.
# 6.	Genre: The genre or category to which the book belongs (e.g., fiction, non-fiction, fantasy, romance).
# With the book dataset containing information about books, authors, original language, publication dates, sales, and genres, there are several potential analyses and tasks that you can perform. Here are some common data analysis and research areas that can be explored with this dataset:
# 7.	Bestselling Book Analysis: Identify the top bestselling books based on their sales figures.
# 8.	Author Analysis: Study the performance and popularity of authors based on the number of books published and total sales.
# 9.	Language and Sales Correlation: Investigate the relationship between the original language of the book and its sales figures.
# 10.	Genre Distribution: Explore the distribution of books across different genres to understand the popularity of each genre.
# 11.	Publication Year Analysis: Analyze book publication trends over the years and identify any patterns.
# 12.	Top Authors by Genre: Identify top authors in specific genres based on their book sales.
# 13.	Book Sales Trends: Study the trend in book sales over time and identify any seasonal patterns.
# 14.	Genre-Based Recommendations: Create book recommendations based on user preferences for specific genres.
# 15.	Language Translation Impact: Analyze the impact of translating books into different languages on their sales.
# 16.	Popular Genres in Different Languages: Compare the popularity of genres in different languages.
# 17.	Top Authors' Impact: Study how books by top authors influence the overall sales.
# .
# 18.	Book Recommendation Engine: Build a book recommendation engine based on sales, genres, and other features.

# %%
df.head()
# Out:
#                                        Book                 Author(s)  \
# 0                      A Tale of Two Cities           Charles Dickens
# 1       The Little Prince (Le Petit Prince)  Antoine de Saint-Exupéry
# 2  Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                  And Then There Were None           Agatha Christie
# 4            Dream of the Red Chamber (紅樓夢)                Cao Xueqin
#
#   Original language  First published  Approximate sales in millions  \
# 0           English             1859                          200.0
# 1            French             1943                          200.0
# 2           English             1997                          120.0
# 3           English             1939                          100.0
# 4           Chinese             1791                          100.0
#
#                 Genre
# 0  Historical fiction
# 1             Novella
# 2             Fantasy
# 3             Mystery
# ...

# %%
df.tail()
# Out:
#                                                   Book  \
# 169                                           The Goal
# 170                                     Fahrenheit 451
# 171                                     Angela's Ashes
# 172  The Story of My Experiments with Truth (સત્યના...
# 173                              Bridget Jones's Diary
#
#                       Author(s) Original language  First published  \
# 169         Eliyahu M. Goldratt           English             1984
# 170                Ray Bradbury           English             1953
# 171               Frank McCourt           English             1996
# 172  Mohandas Karamchand Gandhi          Gujarati             1929
# 173              Helen Fielding           English             1996
#
#      Approximate sales in millions Genre
# 169                           10.0   NaN
# 170                           10.0   NaN
# 171                           10.0   NaN
# 172                           10.0   NaN
# ...

# %%
df.describe()
# Out:
#        First published  Approximate sales in millions
# count       174.000000                     174.000000
# mean       1962.522989                      30.097126
# std          64.268737                      27.957985
# min        1304.000000                      10.000000
# 25%        1947.000000                      14.000000
# 50%        1974.000000                      20.000000
# 75%        1995.000000                      36.300000
# max        2018.000000                     200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Book                           174 non-null    object
#  1   Author(s)                      174 non-null    object
#  2   Original language              174 non-null    object
#  3   First published                174 non-null    int64
#  4   Approximate sales in millions  174 non-null    float64
#  5   Genre                          118 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 8.3+ KB

# %% [markdown]
# ##EDA Process

# %% [markdown]
# ## Visualization imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df.plot(kind='line')
plt.title('count of best selling books counts')
plt.show()

# %%
best_selling_books_describe=df.describe()
best_selling_books_describe
# Out:
#        First published  Approximate sales in millions
# count       174.000000                     174.000000
# mean       1962.522989                      30.097126
# std          64.268737                      27.957985
# min        1304.000000                      10.000000
# 25%        1947.000000                      14.000000
# 50%        1974.000000                      20.000000
# 75%        1995.000000                      36.300000
# max        2018.000000                     200.000000

# %%
sns.heatmap(best_selling_books_describe)
plt.title('describe of best selling books data')
plt.show()

# %% [markdown]
# The heatmap highlights key statistics of best-selling books, showing relationships and patterns in features like price, pages, and ratings.

# %%
df.hist(bins=60,figsize= (20,10))
# Out:
# array([[<Axes: title={'center': 'First published'}>,
#         <Axes: title={'center': 'Approximate sales in millions'}>]],
#       dtype=object)

# %% [markdown]
# The histogram displays the distribution of various features in the dataset, with 60 bins, allowing you to see patterns, trends, and the spread of values across different variables, such as price, ratings, or page counts.

# %% [markdown]
# Counting the books of Author

# %%
#create a bar plot showing the distribution of books by genre
pd.DataFrame(df['Genre'].value_counts()).plot(kind='bar', figsize=(20, 10))
# Out:
# <Axes: xlabel='Genre'>

# %% [markdown]
# The bar plot illustrates the distribution of books across different genres, making it easy to see which genres are most and least popular among the best-selling books.

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Approximate sales in millions'], bins=10, edgecolor='black')
plt.xlabel('Sales (millions)')
plt.ylabel('Frequency')
plt.title('Distribution of Sales')
plt.show()

# %% [markdown]
# The histogram shows the distribution of approximate sales (in millions) for the books, revealing how frequently different sales ranges occur, with peaks indicating the most common sales figures and helping to identify trends in book popularity

# %%
sales_by_genre = df.groupby('Genre')['Approximate sales in millions'].sum().reset_index()
plt.figure(figsize=(20, 5))
sns.barplot(data=sales_by_genre, x='Genre', y='Approximate sales in millions')
plt.xlabel('Genre')
plt.ylabel('Total Sales (millions)')
plt.title('Sales by Genre')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The bar plot displays total sales by genre, highlighting which genres generate the most revenue in millions.

# %%
sales_by_language = df.groupby('Original language')['Approximate sales in millions'].sum().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(data=sales_by_language, x='Original language', y='Approximate sales in millions')
plt.xlabel('Original Language')
plt.ylabel('Total Sales (millions)')
plt.title('Sales by Original Language')
plt.xticks(rotation=45)
plt.show()

# %%
top_authors = df.groupby('Author(s)')['Approximate sales in millions'].sum().nlargest(10)
plt.figure(figsize=(10, 6))
top_authors.plot(kind='bar')
plt.xlabel('Author')
plt.ylabel('Total Sales (millions)')
plt.title('Top Authors by Sales')
plt.xticks(rotation=45)
plt.show()

# %%
sales_by_language = df.groupby('Original language')['Approximate sales in millions'].sum().reset_index()
plt.figure(figsize=(8, 8))
plt.pie(sales_by_language['Approximate sales in millions'], labels=sales_by_language['Original language'], autopct='%1.1f%%')
plt.title('Sales Distribution by Language')
plt.show()

# %% [markdown]
# The pie chart illustrates the sales distribution by language, showing the percentage contribution of each language to total sales.

# %%
Lang = df.groupby('Original language')['Approximate sales in millions'].sum().reset_index().sort_values('Approximate sales in millions', ascending = False).head(5)
col = list(Lang.columns)
sns.barplot(data = Lang, x=col[0], y=col[1])
plt.title('Top Selling by Original Language')
plt.ylabel('Vol Selling (Million)')
# Out:
# Text(0, 0.5, 'Vol Selling (Million)')

# %%
df.groupby('Author(s)')['Book'].count().sort_values(ascending=False).head()
# Out:
# Author(s)
# J. K. Rowling      7
# Suzanne Collins    3
# Dan Brown          3
# Roald Dahl         3
# Ken Follett        2
# Name: Book, dtype: int64

# %% [markdown]
# This list shows the authors who have written the most books in the dataset, ranking them from the highest to the lowest number of books.

# %% [markdown]
#  checking the total sales for each author's books

# %%
# Group by 'Author(s)' and calculate total number of books and total sales
author_stats = df.groupby('Author(s)').agg(
    Total_Books=('Book', 'size'),
    Total_Sales_Millions=('Approximate sales in millions', 'sum')
).reset_index()

# Sort by 'Total Books' in descending order
author_stats = author_stats.sort_values(by='Total_Books', ascending=False)

author_stats.head(10)
# Out:
#                 Author(s)  Total_Books  Total_Sales_Millions
# 58          J. K. Rowling            7                 522.0
# 139       Suzanne Collins            3                  70.0
# 26              Dan Brown            3                 149.0
# 125            Roald Dahl            3                  65.0
# 83            Ken Follett            2                  25.0
# 34            E. L. James            2                  25.6
# 43       Erskine Caldwell            2                  24.0
# 48          George Orwell            2                  50.0
# 1            Albert Camus            2                  22.0
# 112  Patricia Nell Warren            1                  10.0

# %% [markdown]
# This table shows the top 10 authors, listing how many books each has written and their total sales in millions, sorted by the number of books.

# %% [markdown]
# specifically checking the J. K. Rowling's books

# %%
# Filter the dataset for books authored by J.K. Rowling
jk_rowling_books = df[df['Author(s)'] == 'J. K. Rowling']

# Show J.K. Rowling's books along with their sales in millions
jk_rowling_books_sales_in_millions = jk_rowling_books[['Author(s)','Book', 'Approximate sales in millions']]
jk_rowling_books_sales_in_millions
# Out:
#         Author(s)                                       Book  \
# 2   J. K. Rowling   Harry Potter and the Philosopher's Stone
# 10  J. K. Rowling    Harry Potter and the Chamber of Secrets
# 11  J. K. Rowling   Harry Potter and the Prisoner of Azkaban
# 12  J. K. Rowling        Harry Potter and the Goblet of Fire
# 13  J. K. Rowling  Harry Potter and the Order of the Phoenix
# 14  J. K. Rowling     Harry Potter and the Half-Blood Prince
# 15  J. K. Rowling       Harry Potter and the Deathly Hallows
#
#     Approximate sales in millions
# 2                           120.0
# 10                           77.0
# 11                           65.0
# 12                           65.0
# 13                           65.0
# 14                           65.0
# 15                           65.0

# %% [markdown]
# This table displays the books written by J.K. Rowling along with their sales figures in millions, highlighting her contributions to the best-selling titles.

# %% [markdown]
# checking the J. K. Rowling's books genre

# %%
# Show J.K. Rowling's books along with their sales in millions
jk_rowling_books_Genre = jk_rowling_books[['Author(s)','Book', 'Genre']]
jk_rowling_books_Genre
# Out:
#         Author(s)                                       Book    Genre
# 2   J. K. Rowling   Harry Potter and the Philosopher's Stone  Fantasy
# 10  J. K. Rowling    Harry Potter and the Chamber of Secrets  Fantasy
# 11  J. K. Rowling   Harry Potter and the Prisoner of Azkaban  Fantasy
# 12  J. K. Rowling        Harry Potter and the Goblet of Fire  Fantasy
# 13  J. K. Rowling  Harry Potter and the Order of the Phoenix  Fantasy
# 14  J. K. Rowling     Harry Potter and the Half-Blood Prince  Fantasy
# 15  J. K. Rowling       Harry Potter and the Deathly Hallows  Fantasy

# %%
jk_rowling_books_Genre['Genre'].unique()
# Out:
# array(['Fantasy'], dtype=object)

# %% [markdown]
# ##pivot_table

# %%
info_data = jk_rowling_books_sales_in_millions.pivot_table(index='Book',columns='Author(s)',values='Approximate sales in millions')
info_data
# Out:
# Author(s)                                  J. K. Rowling
# Book
# Harry Potter and the Chamber of Secrets             77.0
# Harry Potter and the Deathly Hallows                65.0
# Harry Potter and the Goblet of Fire                 65.0
# Harry Potter and the Half-Blood Prince              65.0
# Harry Potter and the Order of the Phoenix           65.0
# Harry Potter and the Philosopher's Stone           120.0
# Harry Potter and the Prisoner of Azkaban            65.0

# %% [markdown]
# This pivot table shows J.K. Rowling's books as rows and their sales figures in millions as values, making it easy to see how each book performed in terms of sales.

# %% [markdown]
# Adding new features to the pivort table

# %%
info_data['sales_in_millions'] = pd.DataFrame(df.groupby('Book')['Approximate sales in millions'].sum())
info_data
# Out:
# Author(s)                                  J. K. Rowling  sales_in_millions
# Book
# Harry Potter and the Chamber of Secrets             77.0               77.0
# Harry Potter and the Deathly Hallows                65.0               65.0
# Harry Potter and the Goblet of Fire                 65.0               65.0
# Harry Potter and the Half-Blood Prince              65.0               65.0
# Harry Potter and the Order of the Phoenix           65.0               65.0
# Harry Potter and the Philosopher's Stone           120.0              120.0
# Harry Potter and the Prisoner of Azkaban            65.0               65.0

# %%
info_data.groupby('Book')['sales_in_millions'].mean().sort_values(ascending=False).head(7)
# Out:
# Book
# Harry Potter and the Philosopher's Stone     120.0
# Harry Potter and the Chamber of Secrets       77.0
# Harry Potter and the Deathly Hallows          65.0
# Harry Potter and the Goblet of Fire           65.0
# Harry Potter and the Half-Blood Prince        65.0
# Harry Potter and the Order of the Phoenix     65.0
# Harry Potter and the Prisoner of Azkaban      65.0
# Name: sales_in_millions, dtype: float64

# %%
Harry_Potter = info_data.loc["Harry Potter and the Chamber of Secrets":]
Harry_Potter
# Out:
# Author(s)                                  J. K. Rowling  sales_in_millions
# Book
# Harry Potter and the Chamber of Secrets             77.0               77.0
# Harry Potter and the Deathly Hallows                65.0               65.0
# Harry Potter and the Goblet of Fire                 65.0               65.0
# Harry Potter and the Half-Blood Prince              65.0               65.0
# Harry Potter and the Order of the Phoenix           65.0               65.0
# Harry Potter and the Philosopher's Stone           120.0              120.0
# Harry Potter and the Prisoner of Azkaban            65.0               65.0

# %%
similar_to_Harry_Potter = info_data.corrwith(Harry_Potter)

# %% [markdown]
# This analysis compares the sales of J.K. Rowling's books to the sales of "Harry Potter," showing how similar the sales patterns are for each book in relation to "Harry Potter."

# %%
corr_Harry_Potter = pd.DataFrame(similar_to_Harry_Potter,columns=['Correlation'])
corr_Harry_Potter
# Out:
#                    Correlation
# Author(s)
# J. K. Rowling              1.0
# sales_in_millions          1.0

# %% [markdown]
# This table displays the correlation values for J.K. Rowling's books in relation to "Harry Potter," showing how closely the sales of each book match those of "Harry Potter."

# %%
corr_Harry_Potter = pd.concat([corr_Harry_Potter, info_data['sales_in_millions']], axis=1) # Use pd.concat to join the DataFrame and Series. Use axis=1 to concatenate along columns
corr_Harry_Potter
# Out:
#                                            Correlation  sales_in_millions
# J. K. Rowling                                      1.0                NaN
# sales_in_millions                                  1.0                NaN
# Harry Potter and the Chamber of Secrets            NaN               77.0
# Harry Potter and the Deathly Hallows               NaN               65.0
# Harry Potter and the Goblet of Fire                NaN               65.0
# Harry Potter and the Half-Blood Prince             NaN               65.0
# Harry Potter and the Order of the Phoenix          NaN               65.0
# Harry Potter and the Philosopher's Stone           NaN              120.0
# Harry Potter and the Prisoner of Azkaban           NaN               65.0

# %% [markdown]
# This table combines the correlation values with the actual sales figures for J.K. Rowling's books, allowing you to see both the sales amounts and how closely they relate to "Harry Potter."

# %%
corr_Harry_Potter[corr_Harry_Potter['sales_in_millions']>65].sort_values('Correlation',ascending=False)
# Out:
#                                           Correlation  sales_in_millions
# Harry Potter and the Chamber of Secrets           NaN               77.0
# Harry Potter and the Philosopher's Stone          NaN              120.0

# %% [markdown]
# This filtered list shows J.K. Rowling's books that sold more than 65 million copies, sorted by how closely their sales correlate with "Harry Potter," highlighting the most similar books.

# %%
corr_Harry_Potter = pd.DataFrame(similar_to_Harry_Potter,columns=['Correlation'])
corr_Harry_Potter = corr_Harry_Potter.join(info_data['sales_in_millions'])
corr_Harry_Potter[corr_Harry_Potter['sales_in_millions']>65].sort_values('Correlation',ascending=False)
# Out:
# Empty DataFrame
# Columns: [Correlation, sales_in_millions]
# Index: []

# %% [markdown]
# ##Conclusion

# %% [markdown]
# In this project, we looked at best-selling books to find interesting information about authors, genres, and sales. Here are the main points:
#
# Top Authors and Genres: We discovered who the most active authors are and which genres are the most popular, giving us a clear view of what readers like.
# Sales Distribution: Our charts showed how sales differ by genre and language, highlighting the categories that perform best.
# J.K. Rowling's Impact: We focused on J.K. Rowling's books to see her strong sales and how other titles relate to "Harry Potter," showing her continued popularity.
